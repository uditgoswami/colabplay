# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&as-backfill=on"

# %%
content = requests.get(url).content

# %%
flip_soup = BeautifulSoup(content, "html.parser")

# %%
for a in flip_soup.find_all('a', attrs={'class':'_31qSD5'}):
  name=a.find('div', attrs={'class':'_3wU53n'})
  price = a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
  rating = a.find('div', attrs={'class':'hGSR34'})

  print(name.text)
  print(price.text)
  print(rating.text)

# %%
url_2 = "https://www.amazon.in/s?k=laptops&ref=nb_sb_noss_2"
content_2 = requests.get(url_2).content
amazon_soup = BeautifulSoup(content_2, "html.parser")

# %%
for a in amazon_soup.find_all('a', attrs={'class':'a-link-normal a-text-normal'}):
  a.find("span class", attrs={"class":"a-size-medium a-color-base a-text-normal"})
  print(a.text)
# Out:
# Lenovo Ideapad S145 AMD A6-9225 15.6 inch HD Thin and Light Laptop (4GB/1TB/Windows 10/Grey/1.85Kg), 81N30063IN
#
#
# Lenovo V145-AMD-A6 15.6 inch HD Thin and Light Laptop (4GB RAM/ 500GB HDD/ Windows 10 Home with Lifetime Validity/ Black/ 2.1 kg), 81MT004BIH
#
#
# Dell Inspiron 3567 Intel Core i3 7th Gen 15.6-inch FHD Laptop (4GB/1TB HDD/Windows 10 Home + MS Office/Black/2.5kg)
#
#
# HP 14-inch Laptop (9th Gen A4-9125/4GB/1TB HDD/Win 10/MS Office 2019/AMD Radeon R3 Graphics), 14-cm0123au
#
#
# Acer Aspire ES 15 15.6-inch Laptop (E1-7010/4GB/1TB/Linux/Integrated Graphics), Midnight Black
#
#
# ASUS VivoBook 14 X409UA-EK341T Intel Core i3 7th Gen 14-inch FHD Compact and Light Laptop (4GB RAM/1TB HDD/Windows 10/Integrated Graphics/FP Reader/1.60 kg), Transparent Silver
#
#
# Dell Vostro 3581 15.6-inch HD Laptop (7th Gen Core i3-7020U/4GB/1TB HDD/Windows 10 + MS Office/Intel HD Graphics/Black)
#
#
# ...
